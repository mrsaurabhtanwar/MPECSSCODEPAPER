# %% [markdown]
# # MPECSS - NosBench Benchmark (Group 5 of 6)This notebook runs **Group 5** of the NosBench benchmark suite.- **Dataset**: NosBench (Group 5)- **Problems**: 100 (balanced small/medium/large split)- **Resume support**: built in via `kaggle_setup/resumable_benchmark.py`**Prerequisites:**1. Add the `mpecss-benchmarks` dataset to this notebook2. Enable Internet accessRun the cells in order. After a Kaggle restart, re-run cells 1-3, then use the **Resume** cell.

# %% [markdown]
# ## 1. Configuration

# %%
# NosBench Group 5 Configurationimport osDATASET = 'nosbench'GROUP = 5RUN_TAG = f'Kaggle_NosBench_Group{GROUP}'WORKERS = 4TIMEOUT = 3600SAVE_LOGS = TrueSHUFFLE = True# Repository (code)REPO_DIR = "/kaggle/working/MPECSSCODEPAPER"REPO_GIT_URL = "https://github.com/mrsaurabhtanwar/MPECSSCODEPAPER.git"# IMPORTANT: Results go directly to /kaggle/working/outputs to persist after session endsOUTPUT_DIR = "/kaggle/working/outputs"# Benchmark data path (from Kaggle dataset - NOT from repo)DATASET_PATH = '/kaggle/input/mpecss-benchmarks/benchmarks/nosbench/nosbench-json'# Problem list for this group (from repo)PROBLEM_LIST = f"{REPO_DIR}/kaggle_setup/nosbench_splits/nosbench_group{GROUP}_problems.txt"# Verify dataset is attachedif not os.path.exists(DATASET_PATH):    print("[ERROR] Dataset not found!")    print("Please add the 'mpecss-benchmarks' dataset to this notebook.")else:    print(f"[OK] Dataset found: {DATASET_PATH}")    print(f"[OK] Results will save to: {OUTPUT_DIR}")

# %% [markdown]
# ## 2. Prepare The Repository

# %%
from pathlib import Path
import shutil
import subprocess
import sys

repo_path = Path(REPO_DIR)
REPO_COMMIT = "SET_RELEASE_COMMIT"
if REPO_COMMIT == "SET_RELEASE_COMMIT":
    raise RuntimeError("Set REPO_COMMIT to the pushed release commit before the final Kaggle run.")

if repo_path.exists():
    shutil.rmtree(repo_path)

print(f"Cloning: {REPO_GIT_URL} @ {REPO_COMMIT}")
subprocess.run(["git", "clone", "--depth", "1", REPO_GIT_URL, str(repo_path)], check=True)
subprocess.run(["git", "checkout", REPO_COMMIT], check=True, cwd=str(repo_path))
sys.path.insert(0, str(repo_path))
print(f"[OK] Repository ready")

# %% [markdown]
# ## 3. Install Dependencies

# %%
# %%bash
# cd /kaggle/working/MPECSSCODEPAPER
# pip install -q --upgrade pip
# pip install -q -e .
# echo "[OK] Installation complete"

# %% [markdown]
# ## 4. Data Path Setup

# %%
import os

print(f"Dataset path: {DATASET_PATH}")
print(f"Problem list: {PROBLEM_LIST}")

if os.path.exists(DATASET_PATH):
    count = len([f for f in os.listdir(DATASET_PATH) if f.endswith('.json')])
    print(f"[OK] Total problems in dataset: {count}")
else:
    print(f"[ERROR] Dataset path not found!")

if os.path.exists(PROBLEM_LIST):
    with open(PROBLEM_LIST) as f:
        group_count = sum(1 for line in f if line.strip() and not line.startswith('#'))
    print(f"[OK] Problems in Group {GROUP}: {group_count}")
else:
    print(f"[ERROR] Problem list not found!")

# %% [markdown]
# ## 5. Inspect The Kaggle Instance

# %%
import multiprocessing
import platform
import psutil

print("=" * 60)
print("System Information")
print("=" * 60)
print(f"Platform: {platform.platform()}")
print(f"Python: {platform.python_version()}")
print(f"Logical CPU cores: {multiprocessing.cpu_count()}")

mem = psutil.virtual_memory()
print(f"Total RAM: {mem.total / 1024**3:.1f} GB")
print(f"Available RAM: {mem.available / 1024**3:.1f} GB")
print("=" * 60)

# %% [markdown]
# ## 6. Run Preflight Checks

# %%
# %%bash
# set -euo pipefail
# cd /kaggle/working/MPECSSCODEPAPER
# python scripts/preflight_checks.py

# %% [markdown]
# ## 7. Load The Runner Helper

# %%
import subprocess
import sys

def run_benchmark(resume=False, summary=False):
    cmd = [
        sys.executable,
        f"{str(REPO_DIR)}/kaggle_setup/resumable_benchmark.py",
        "--dataset", DATASET,
        "--repo-dir", str(REPO_DIR),
        "--tag", RUN_TAG,
        "--workers", str(WORKERS),
        "--timeout", str(TIMEOUT),
        "--path", str(DATASET_PATH),
        "--problem-list", str(PROBLEM_LIST),
        "--output-dir", str(OUTPUT_DIR),  # CRITICAL: Save to persistent location
    ]
    if SAVE_LOGS: cmd.append("--save-logs")
    if SHUFFLE: cmd.append("--shuffle")
    if resume: cmd.append("--resume-latest")
    if summary: cmd.append("--summary-only")
    
    print("+ " + " ".join(str(x) for x in cmd))
    subprocess.run(cmd)

# %% [markdown]
# ## 8. Launch A Fresh Run

# %%
run_benchmark()

# %% [markdown]
# ## 9. Resume After A Kaggle Restart

# %%
run_benchmark(resume=True)

# %% [markdown]
# ## 10. Progress Summary

# %%
run_benchmark(summary=True)

# %% [markdown]
# ## 11. Copy Results For Download

# %%
from pathlib import Path
import shutil

output_dir = Path(OUTPUT_DIR)
if not output_dir.exists():
    print(f"[WARN] Output directory not found: {output_dir}")
else:
    archive = shutil.make_archive(str(output_dir), "zip", root_dir=str(output_dir))
    print(f"[OK] Results directory: {output_dir}")
    print(f"[OK] Download archive: {archive}")
    for item in sorted(output_dir.iterdir()):
        print(item)

# %% [markdown]
# ## 12. Software Versions For Your Paper

# %%
import casadi
import matplotlib
import numpy
import pandas
import platform
import psutil
import scipy

print("Software Versions")
print("=" * 40)
print(f"Python: {platform.python_version()}")
print(f"NumPy: {numpy.__version__}")
print(f"SciPy: {scipy.__version__}")
print(f"Pandas: {pandas.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"CasADi: {casadi.__version__}")
print(f"psutil: {psutil.__version__}")
print("=" * 40)
