# %% [markdown]
# # MPECSS - NosBench Group 1
#
# This notebook is aligned with the current `Org-MPECSS` benchmark flow.
#
# - **Dataset**: NosBench Group 1
# - **Problems**: 201
# - **Resume support**: built in via `kaggle_setup/resumable_benchmark.py`
# - **Repo source**: GitHub (always clones fresh)
#
# Run the cells in order. After a Kaggle restart, rerun the repository and
# install cells, then run the **Resume** cell.

# %% [markdown]
# ## 1. Configuration
#
# The notebook is pre-configured to clone from GitHub. Adjust `WORKERS`,
# `TIMEOUT`, or other settings below if needed.

# %%
# Notebook configuration
DATASET = 'nosbench'
RUN_TAG = 'Kaggle_NosBench_Group1'
EXPECTED_PROBLEMS = 201

WORKERS = 4  # Match Kaggle's 4 CPU cores
TIMEOUT = 3600
NUM_PROBLEMS = None
PROBLEM_FILTER = ""
MEM_LIMIT_GB = None
SAVE_LOGS = True
SORT_BY_SIZE = False
SHUFFLE = True
RETRY_FAILED_ON_RESUME = False
DATASET_PATH_OVERRIDE = '/kaggle/working/Org-MPECSS/benchmarks/nosbench/nosbench-json-group1'

# Repository source - always clone fresh from GitHub
REPO_DIR = "/kaggle/working/Org-MPECSS"
REPO_GIT_URL = "https://github.com/mrsaurabhtanwar/Org-MPECSS.git"

# %% [markdown]
# ## 2. Prepare The Repository

# %%
from pathlib import Path
import shutil
import subprocess
import sys

REPO_DIR = Path(REPO_DIR)

# Always clone fresh from GitHub to get latest code
if REPO_DIR.exists():
    shutil.rmtree(REPO_DIR)

print(f"Cloning repo from Git: {REPO_GIT_URL}")
subprocess.run(["git", "clone", REPO_GIT_URL, str(REPO_DIR)], check=True)

# Add to Python path
sys.path.insert(0, str(REPO_DIR))

print(f"Repository ready at: {REPO_DIR}")

# %% [markdown]
# ## 3. Install Dependencies

# %%
# %%bash
# set -euo pipefail
# cd /kaggle/working/Org-MPECSS
#
# python -m pip install -q --upgrade pip
# python -m pip install -q -e .
#
# echo "[OK] Editable install completed"

# %% [markdown]
# ## 4. Prepare NosBench Group 1

# %%
import os
import shutil

GROUP_PROBLEMS = """2BCLS_002_001_002_3_GL_CLS_3_ELC_0.json\n2BCLS_002_001_002_3_GL_CLS_7_ELC_0.json\n2BCLS_003_001_002_3_GL_CLS_3_ELC_0.json\n3CPCLS_001_030_003_2_RIIA_CLS_3_ELC_0.json\n3CPCLS_001_030_003_2_RIIA_CLS_4_ELC_0.json\n3CPCLS_003_015_003_2_RIIA_CLS_3_ELC_0.json\n3CPTF_001_020_003_1_RIIA_STEP_3_IEC_0.json\n3CPTF_001_030_003_1_RIIA_STEP_4_IEC_0.json\n3CPTF_002_020_003_1_RIIA_STEP_4_IEC_0.json\n3CPTF_002_020_003_1_RIIA_STEP_7_IEC_0.json\n3CPTF_003_020_003_1_RIIA_STEP_4_IEC_0.json\n3CPTF_003_030_003_1_RIIA_STEP_7_IEC_0.json\n986EQ_001_001_003_2_GL_STEP_7_FIL_0.json\n986EQ_001_001_003_2_GL_STEWART_7_FIL_0.json\n986EQ_002_001_003_2_GL_STEP_3_FIL_0.json\n986EQ_002_001_003_2_GL_STEWART_3_FIL_0.json\n986EQ_002_001_003_2_GL_STEWART_4_FIL_0.json\n986FO_001_001_002_3_
    problem_name = entry.strip()
    if not problem_name:
        continue
    src = os.path.join(SRC_DIR, problem_name)
    dst = os.path.join(DST_DIR, problem_name)
    if os.path.exists(src):
        shutil.copy2(src, dst)
        copied += 1

print(f"Prepared NosBench Group 1: {copied} / 201 problems")

# %% [markdown]
# ## 5. Inspect The Kaggle Instance

# %%
import multiprocessing
import platform
import psutil

print("=" * 60)
print("System Information")
print("=" * 60)
print(f"Platform: {platform.platform()}")
print(f"Python: {platform.python_version()}")
print(f"Logical CPU cores: {multiprocessing.cpu_count()}")

mem = psutil.virtual_memory()
print(f"Total RAM: {mem.total / 1024**3:.1f} GB")
print(f"Available RAM: {mem.available / 1024**3:.1f} GB")
print("=" * 60)

# %% [markdown]
# ## 6. Run Preflight Checks

# %%
# %%bash
# set -euo pipefail
# cd /kaggle/working/Org-MPECSS
# python scripts/preflight_checks.py

# %% [markdown]
# ## 7. Load The Runner Helper

# %%
from pathlib import Path
import subprocess
import sys

REPO_DIR = Path(REPO_DIR)
WRAPPER = REPO_DIR / "kaggle_setup" / "resumable_benchmark.py"

def run_benchmark(resume_latest=False, summary_only=False):
    command = [
        sys.executable,
        str(WRAPPER),
        "--dataset",
        DATASET,
        "--repo-dir",
        str(REPO_DIR),
        "--tag",
        RUN_TAG,
        "--workers",
        str(WORKERS),
        "--timeout",
        str(TIMEOUT),
        "--skip-preflight",
    ]

    if SAVE_LOGS:
        command.append("--save-logs")
    if SORT_BY_SIZE:
        command.append("--sort-by-size")
    if SHUFFLE:
        command.append("--shuffle")
    else:
        command.append("--no-shuffle")
    if PROBLEM_FILTER:
        command.extend(["--problem", PROBLEM_FILTER])
    if NUM_PROBLEMS is not None:
        command.extend(["--num-problems", str(NUM_PROBLEMS)])
    if MEM_LIMIT_GB is not None:
        command.extend(["--mem-limit-gb", str(MEM_LIMIT_GB)])
    if DATASET_PATH_OVERRIDE:
        command.extend(["--path", DATASET_PATH_OVERRIDE])
    if RETRY_FAILED_ON_RESUME:
        command.append("--retry-failed")
    if resume_latest:
        command.append("--resume-latest")
    if summary_only:
        command.append("--summary-only")

    print("+", " ".join(command))
    subprocess.run(command, check=True)

# %% [markdown]
# ## 8. Launch A Fresh Run

# %%
run_benchmark()

# %% [markdown]
# ## 9. Resume After A Kaggle Restart

# %%
run_benchmark(resume_latest=True)

# %% [markdown]
# ## 10. Progress Summary

# %%
run_benchmark(summary_only=True)

# %% [markdown]
# ## 11. Copy Results For Download

# %%
# %%bash
# set -euo pipefail
# mkdir -p /kaggle/working/outputs
# cp -r /kaggle/working/Org-MPECSS/results/* /kaggle/working/outputs/ || true
#
# echo "[OK] Results copied to /kaggle/working/outputs/"
# echo "Download from the Kaggle file browser or output panel"

# %% [markdown]
# ## 12. Software Versions For Your Paper

# %%
import casadi
import matplotlib
import numpy
import pandas
import platform
import psutil
import scipy

print("Software Versions")
print("=" * 40)
print(f"Python: {platform.python_version()}")
print(f"NumPy: {numpy.__version__}")
print(f"SciPy: {scipy.__version__}")
print(f"Pandas: {pandas.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"CasADi: {casadi.__version__}")
print(f"psutil: {psutil.__version__}")
print("=" * 40)
